# %% [markdown]
# From: https://github.com/bdecon/econ_data/blob/master/APIs/IMF.ipynb

# %% [markdown]
# # Search medatadata

# %%
import requests
import pandas as pd
import numpy as np

# %%
key = 'Dataflow'  # Method with series information
t = 'Price'  # Term to find in series names
sl = requests.get(f'{url}{key}').json()['Structure']['Dataflows']['Dataflow']
# Print list of series containing text t
for s in (s for s in sl if t in s['Name']['#text']): 
    code = s['KeyFamilyRef']['KeyFamilyID']
    print(f"{s['Name']['#text']}: {code}")
# Out:
# Consumer Price Index (CPI): CPI
# Prices, Production, Labor and Trade (PPLT): PPLT
# Primary Commodity Price System (PCPS): PCPS

# %% [markdown]
# Print the dimensions for a given series, "CPI"

# %%
key = 'DataStructure/CPI'  # Method / series
dl = requests.get(f'{url}{key}').json()\
    ['Structure']['KeyFamilies']['KeyFamily']['Components']['Dimension']
for n, d in enumerate(dl):
    print(f"Dimension {n+1}: {d['@codelist']}")
# Out:
# Dimension 1: CL_FREQ
# Dimension 2: CL_AREA_CPI
# Dimension 3: CL_INDICATOR_CPI

# %% [markdown]
# See what values are acceptable for dimension "CL_INDICATOR_CPI"

# %%
# Example: codes for dimension 3
key = f"CodeList/{dl[2]['@codelist']}"
cl = requests.get(f'{url}{key}').json()['Structure']['CodeLists']['CodeList']['Code']
for c in cl:
    print(f"{c['Description']['#text']}: {c['@value']}")
# Out:
# Consumer Price Index, All items: PCPI_IX
# Food and non-alcoholic beverages: PCPIF_IX
# Alcoholic Beverages, Tobacco, and Narcotics: PCPIFBT_IX
# Clothing and footwear: PCPIA_IX
# Housing, Water, Electricity, Gas and Other Fuels: PCPIH_IX
# Furnishings, household equipment and routine household maintenance: PCPIHO_IX
# Health: PCPIM_IX
# Transport: PCPIT_IX
# Communication: PCPIEC_IX
# Recreation and culture: PCPIR_IX
# Education: PCPIED_IX
# Restaurants and hotels: PCPIRE_IX
# Miscellaneous goods and services: PCPIO_IX
# Consumer Price Index, All items, Overlap: PCPI_OLP_IX
# Food and non-alcoholic beverages, Overlap: PCPIF_OLP_IX
# Alcoholic Beverages, Tobacco, and Narcotics, Overlap: PCPIFBT_OLP_IX
# Clothing and footwear, Overlap: PCPIA_OLP_IX
# Housing, Water, Electricity, Gas and Other Fuels, Overlap: PCPIH_OLP_IX
# Furnishings, household equipment and routine household maintenance, Overlap: PCPIHO_OLP_IX
# Health, Overlap: PCPIM_OLP_IX
# Transport, Overlap: PCPIT_OLP_IX
# Communication, Overlap: PCPIEC_OLP_IX
# Recreation and culture, Overlap: PCPIR_OLP_IX
# Education, Overlap: PCPIED_OLP_IX
# Restaurants and hotels, Overlap: PCPIRE_OLP_IX
# Miscellaneous goods and services, Overlap: PCPIO_OLP_IX
# Food and non-alcoholic beverages, Weight: PCPIF_WT
# Alcoholic Beverages, Tobacco, and Narcotics, Weight: PCPIFBT_WT
# Clothing and footwear, Weight: PCPIA_WT
# Housing, Water, Electricity, Gas and Other Fuels, Weight: PCPIH_WT
# Furnishings, household equipment and routine household maintenance, Weight: PCPIHO_WT
# Health, Weight: PCPIM_WT
# Transport, Weight: PCPIT_WT
# Communication, Weight: PCPIEC_WT
# Recreation and culture, Weight: PCPIR_WT
# Education, Weight: PCPIED_WT
# Restaurants and hotels, Weight: PCPIRE_WT
# Miscellaneous goods and services, Weight: PCPIO_WT
# Consumer Price Index, All items, Harmonized: PCPIHA_IX
# Food and non-alcoholic beverages, Harmonized: PCPIHAF_IX
# Alcoholic Beverages, Tobacco, and Narcotics, Harmonized: PCPIHABT_IX
# Clothing and footwear, Harmonized: PCPIHAA_IX
# Housing, Water, Electricity, Gas and Other Fuels, Harmonized: PCPIHAH_IX
# Furnishings, household equipment and routine household maintenance, Harmonized: PCPIHAHO_IX
# Health, Harmonized: PCPIHAM_IX
# Transport, Harmonized: PCPIHAT_IX
# Communication, Harmonized: PCPIHAC_IX
# Recreation and culture, Harmonized: PCPIHARC_IX
# Education, Harmonized: PCPIHAED_IX
# Restaurants and hotels, Harmonized: PCPIHARE_IX
# Miscellaneous goods and services, Harmonized: PCPIHAO_IX
# Consumer Price Index, All items, Harmonized, Overlap: PCPIHA_OLP_IX
# Food and non-alcoholic beverages, Harmonized, Overlap: PCPIHAF_OLP_IX
# Alcoholic Beverages, Tobacco, and Narcotics, Harmonized, Overlap: PCPIHABT_OLP_IX
# Clothing and footwear, Harmonized, Overlap: PCPIHAA_OLP_IX
# Housing, Water, Electricity, Gas and Other Fuels, Harmonized, Overlap: PCPIHAH_OLP_IX
# Furnishings, household equipment and routine household maintenance, Harmonized, Overlap: PCPIHAHO_OLP_IX
# Health, Harmonized, Overlap: PCPIHAM_OLP_IX
# Transport, Harmonized, Overlap: PCPIHAT_OLP_IX
# Communication, Harmonized, Overlap: PCPIHAC_OLP_IX
# Recreation and culture, Harmonized, Overlap: PCPIHARC_OLP_IX
# Education, Harmonized, Overlap: PCPIHAED_OLP_IX
# Restaurants and hotels, Harmonized, Overlap: PCPIHARE_OLP_IX
# Miscellaneous goods and services, Harmonized, Overlap: PCPIHAO_OLP_IX
# Food and non-alcoholic beverages, Harmonized, Weight: PCPIHAF_WT
# Alcoholic Beverages, Tobacco, and Narcotics, Harmonized, Weight: PCPIHABT_WT
# Clothing and footwear, Harmonized, Weight: PCPIHAA_WT
# Housing, Water, Electricity, Gas and Other Fuels, Harmonized, Weight: PCPIHAH_WT
# Furnishings, household equipment and routine household maintenance, Harmonized, Weight: PCPIHAHO_WT
# Health, Harmonized, Weight: PCPIHAM_WT
# Transport, Harmonized, Weight: PCPIHAT_WT
# Communication, Harmonized, Weight: PCPIHAC_WT
# Recreation and culture, Harmonized, Weight: PCPIHARC_WT
# Education, Harmonized, Weight: PCPIHAED_WT
# Restaurants and hotels, Harmonized, Weight: PCPIHARE_WT
# Miscellaneous goods and services, Harmonized, Weight: PCPIHAO_WT
# Consumer Price Index, All items, Standard Reference Period: PCPI_SRP_IX
# Food and non-alcoholic beverages, Standard Reference Period: PCPIF_SRP_IX
# Alcoholic Beverages, Tobacco, and Narcotics, Standard Reference Period: PCPIFBT_SRP_IX
# Clothing and footwear, Standard Reference Period: PCPIA_SRP_IX
# Housing, Water, Electricity, Gas and Other Fuels, Standard Reference Period: PCPIH_SRP_IX
# Furnishings, household equipment and routine household maintenance, Standard Reference Period: PCPIHO_SRP_IX
# Health, Standard Reference Period: PCPIM_SRP_IX
# Transport, Standard Reference Period: PCPIT_SRP_IX
# Communication, Standard Reference Period: PCPIEC_SRP_IX
# Recreation and culture, Standard Reference Period: PCPIR_SRP_IX
# Education, Standard Reference Period: PCPIED_SRP_IX
# Restaurants and hotels, Standard Reference Period: PCPIRE_SRP_IX
# Miscellaneous goods and services, Standard Reference Period: PCPIO_SRP_IX
# Consumer Price Index, All items, Percentage change, Previous period: PCPI_PC_PP_PT
# Food and non-alcoholic beverages, Percentage change, Previous period: PCPIF_PC_PP_PT
# Alcoholic Beverages, Tobacco, and Narcotics, Percentage change, Previous period: PCPIFBT_PC_PP_PT
# Clothing and footwear, Percentage change, Previous period: PCPIA_PC_PP_PT
# Housing, Water, Electricity, Gas and Other Fuels, Percentage change, Previous period: PCPIH_PC_PP_PT
# Furnishings, household equipment and routine household maintenance, Percentage change, Previous period: PCPIHO_PC_PP_PT
# Health, Percentage change, Previous period: PCPIM_PC_PP_PT
# Transport, Percentage change, Previous period: PCPIT_PC_PP_PT
# Communication, Percentage change, Previous period: PCPIEC_PC_PP_PT
# Recreation and culture, Percentage change, Previous period: PCPIR_PC_PP_PT
# Education, Percentage change, Previous period: PCPIED_PC_PP_PT
# Restaurants and hotels, Percentage change, Previous period: PCPIRE_PC_PP_PT
# Miscellaneous goods and services, Percentage change, Previous period: PCPIO_PC_PP_PT
# Consumer Price Index, All items, Percentage change, Previous year: PCPI_PC_CP_A_PT
# Food and non-alcoholic beverages, Percentage change, Previous year: PCPIF_PC_CP_A_PT
# Alcoholic Beverages, Tobacco, and Narcotics, Percentage change, Previous year: PCPIFBT_PC_CP_A_PT
# Clothing and footwear, Percentage change, Previous year: PCPIA_PC_CP_A_PT
# Housing, Water, Electricity, Gas and Other Fuels, Percentage change, Previous year: PCPIH_PC_CP_A_PT
# Furnishings, household equipment and routine household maintenance, Percentage change, Previous year: PCPIHO_PC_CP_A_PT
# Health, Percentage change, Previous year: PCPIM_PC_CP_A_PT
# Transport, Percentage change, Previous year: PCPIT_PC_CP_A_PT
# Communication, Percentage change, Previous year: PCPIEC_PC_CP_A_PT
# Recreation and culture, Percentage change, Previous year: PCPIR_PC_CP_A_PT
# Education, Percentage change, Previous year: PCPIED_PC_CP_A_PT
# Restaurants and hotels, Percentage change, Previous year: PCPIRE_PC_CP_A_PT
# Miscellaneous goods and services, Percentage change, Previous year: PCPIO_PC_CP_A_PT
# Consumer Price Index, All items, Harmonized, Standard Reference Period: PCPIHA_SRP_IX
# Food and non-alcoholic beverages, Harmonized, Standard Reference Period: PCPIHAF_SRP_IX
# Alcoholic Beverages, Tobacco, and Narcotics, Harmonized, Standard Reference Period: PCPIHABT_SRP_IX
# Clothing and footwear, Harmonized, Standard Reference Period: PCPIHAA_SRP_IX
# Housing, Water, Electricity, Gas and Other Fuels, Harmonized, Standard Reference Period: PCPIHAH_SRP_IX
# Furnishings, household equipment and routine household maintenance, Harmonized, Standard Reference Period: PCPIHAHO_SRP_IX
# Health, Harmonized, Standard Reference Period: PCPIHAM_SRP_IX
# Transport, Harmonized, Standard Reference Period: PCPIHAT_SRP_IX
# Communication, Harmonized, Standard Reference Period: PCPIHAC_SRP_IX
# Recreation and culture, Harmonized, Standard Reference Period: PCPIHARC_SRP_IX
# Education, Harmonized, Standard Reference Period: PCPIHAED_SRP_IX
# Restaurants and hotels, Harmonized, Standard Reference Period: PCPIHARE_SRP_IX
# Miscellaneous goods and services, Harmonized, Standard Reference Period: PCPIHAO_SRP_IX
# Consumer Price Index, All items, Harmonized, Percentage change, Previous period: PCPIHA_PC_PP_PT
# Food and non-alcoholic beverages, Harmonized, Percentage change, Previous period: PCPIHAF_PC_PP_PT
# Alcoholic Beverages, Tobacco, and Narcotics, Harmonized, Percentage change, Previous period: PCPIHABT_PC_PP_PT
# Clothing and footwear, Harmonized, Percentage change, Previous period: PCPIHAA_PC_PP_PT
# Housing, Water, Electricity, Gas and Other Fuels, Harmonized, Percentage change, Previous period: PCPIHAH_PC_PP_PT
# Furnishings, household equipment and routine household maintenance, Harmonized, Percentage change, Previous period: PCPIHAHO_PC_PP_PT
# Health, Harmonized, Percentage change, Previous period: PCPIHAM_PC_PP_PT
# Transport, Harmonized, Percentage change, Previous period: PCPIHAT_PC_PP_PT
# Communication, Harmonized, Percentage change, Previous period: PCPIHAC_PC_PP_PT
# Recreation and culture, Harmonized, Percentage change, Previous period: PCPIHARC_PC_PP_PT
# Education, Harmonized, Percentage change, Previous period: PCPIHAED_PC_PP_PT
# Restaurants and hotels, Harmonized, Percentage change, Previous period: PCPIHARE_PC_PP_PT
# Miscellaneous goods and services, Harmonized, Percentage change, Previous period: PCPIHAO_PC_PP_PT
# Consumer Price Index, All items, Harmonized, Percentage change, Previous year: PCPIHA_PC_CP_A_PT
# Food and non-alcoholic beverages, Harmonized, Percentage change, Previous year: PCPIHAF_PC_CP_A_PT
# Alcoholic Beverages, Tobacco, and Narcotics, Harmonized, Percentage change, Previous year: PCPIHABT_PC_CP_A_PT
# Clothing and footwear, Harmonized, Percentage change, Previous year: PCPIHAA_PC_CP_A_PT
# Housing, Water, Electricity, Gas and Other Fuels, Harmonized, Percentage change, Previous year: PCPIHAH_PC_CP_A_PT
# Furnishings, household equipment and routine household maintenance, Harmonized, Percentage change, Previous year: PCPIHAHO_PC_CP_A_PT
# Health, Harmonized, Percentage change, Previous year: PCPIHAM_PC_CP_A_PT
# Transport, Harmonized, Percentage change, Previous year: PCPIHAT_PC_CP_A_PT
# Communication, Harmonized, Percentage change, Previous year: PCPIHAC_PC_CP_A_PT
# Recreation and culture, Harmonized, Percentage change, Previous year: PCPIHARC_PC_CP_A_PT
# Education, Harmonized, Percentage change, Previous year: PCPIHAED_PC_CP_A_PT
# Restaurants and hotels, Harmonized, Percentage change, Previous year: PCPIHARE_PC_CP_A_PT
# Miscellaneous goods and services, Harmonized, Percentage change, Previous year: PCPIHAO_PC_CP_A_PT
# Food and non-alcoholic beverages, Weight, Percent: PCPIF_WT_PT
# Alcoholic Beverages, Tobacco, and Narcotics, Weight, Percent: PCPIFBT_WT_PT
# Clothing and footwear, Weight, Percent: PCPIA_WT_PT
# Housing, Water, Electricity, Gas and Other Fuels, Weight, Percent: PCPIH_WT_PT
# Furnishings, household equipment and routine household maintenance, Weight, Percent: PCPIHO_WT_PT
# Health, Weight, Percent: PCPIM_WT_PT
# Transport, Weight, Percent: PCPIT_WT_PT
# Communication, Weight, Percent: PCPIEC_WT_PT
# Recreation and culture, Weight, Percent: PCPIR_WT_PT
# Education, Weight, Percent: PCPIED_WT_PT
# Restaurants and hotels, Weight, Percent: PCPIRE_WT_PT
# Miscellaneous goods and services, Weight, Percent: PCPIO_WT_PT
# Clothing and footwear, Harmonized, Weight, Percent: PCPIHAA_WT_PT
# Alcoholic Beverages, Tobacco, and Narcotics, Harmonized, Weight, Percent: PCPIHABT_WT_PT
# Communication, Harmonized, Weight, Percent: PCPIHAC_WT_PT
# Education, Harmonized, Weight, Percent: PCPIHAED_WT_PT
# Food and non-alcoholic beverages, Harmonized, Weight, Percent: PCPIHAF_WT_PT
# Furnishings, household equipment and routine household maintenance, Harmonized, Weight, Percent: PCPIHAHO_WT_PT
# Housing, Water, Electricity, Gas and Other Fuels, Harmonized, Weight, Percent: PCPIHAH_WT_PT
# Health, Harmonized, Weight, Percent: PCPIHAM_WT_PT
# Miscellaneous goods and services, Harmonized, Weight, Percent: PCPIHAO_WT_PT
# Recreation and culture, Harmonized, Weight, Percent: PCPIHARC_WT_PT
# Restaurants and hotels, Harmonized, Weight, Percent: PCPIHARE_WT_PT
# Transport, Harmonized, Weight, Percent: PCPIHAT_WT_PT

# %% [markdown]
# # Hardcoded Country Codes

# %%
countries_list = ['AW','AF','AO','AL','AD','AE','AR','AM','AS','AG','AU','AT','AZ','BI','BE','BJ','BF','BD','BG','BH','BS','BA','BY','BZ','BM','BO','BR','BB','BN','BT','BW','CF','CA','CH','JG','CL','CN','CI','CM','CD','CG','CO','KM','CV','CR','CU','CW','KY','CY','CZ','DE','DJ','DM','DK','DO','DZ','EC','EG','ER','ES','EE','ET','FI','FJ','FR','FO','FM','GA','GB','GE','GH','GI','GN','GM','GW','GQ','GR','GD','GL','GT','GU','GY','HK','HN','HR','HT','HU','ID','IM','IN','IE','IR','IQ','IS','IL','IT','JM','JO','JP','KZ','KE','KG','KH','KI','KN','KR','KW','LA','LB','LR','LY','LC','LI','LK','LS','LT','LU','LV','MO','MF','MA','MC','MD','MG','MV','MX','MH','MK','ML','MT','MM','ME','MN','MP','MZ','MR','MU','MW','MY','NA','NC','NE','NG','NI','NL','NO','NP','NR','NZ','OM','PK','PA','PE','PH','PW','PG','PL','PR','KP','PT','PY','PS','PF','QA','RO','RU','RW','SA','SD','SN','SG','SB','SL','SV','SM','SO','RS','SS','ST','SR','SK','SI','SE','SZ','SX','SC','SY','TC','TD','TG','TH','TJ','TM','TL','TO','TT','TN','TR','TV','TW','TZ','UG','UA','UY','US','UZ','VC','VE','VG','VI','VN','VU','WS','XK','YE','ZA','ZM','ZW']

# %%
# the API accepts inputs in the following format
countries_string = '...'

# %%
# list of countries from https://www.imf.org/external/pubs/ft/weo/2014/01/weodata/co.xlsx
countries_stringn_2 = '...'

# %%
url = 'http://dataservices.imf.org/REST/SDMX_JSON.svc/'
param = [('dataset', 'IFS'), # International Financial Statistics 
         ('freq', 'A'), # Frequency M: monthly, A:annual
         ('country', ''), #country codes
         ('series', 'PCPI_IX'), #consumer price index, see http://data.imf.org/api/document/download?key=61720091
         ('start', '?startPeriod=2017')]
series = '.'.join([i[1] for i in param[1:4]])

key = f'CompactData/{param[0][1]}/{series}{param[-1][1]}'
r = requests.get(f'{url}{key}').json() # Combine API url with key specific to data request
r
# Out:
# {'CompactData': {'@xmlns:xsi': 'http://www.w3.org/2001/XMLSchema-instance',
#   '@xmlns:xsd': 'http://www.w3.org/2001/XMLSchema',
#   '@xsi:schemaLocation': 'http://www.SDMX.org/resources/SDMXML/schemas/v2_0/message https://registry.sdmx.org/schemas/v2_0/SDMXMessage.xsd http://dataservices.imf.org/compact/IFS http://dataservices.imf.org/compact/IFS.xsd',
#   '@xmlns': 'http://www.SDMX.org/resources/SDMXML/schemas/v2_0/message',
#   'Header': {'ID': 'b3f74b68-22ac-4f3d-9b6a-d36799db2e64',
#    'Test': 'false',
#    'Prepared': '2020-02-12T16:27:55',
#    'Sender': {'@id': '1C0',
#     'Name': {'@xml:lang': 'en', '#text': 'IMF'},
#     'Contact': {'URI': 'http://www.imf.org',
#      'Telephone': '+ 1 (202) 623-6220'}},
#    'Receiver': {'@id': 'ZZZ'},
#    'DataSetID': 'IFS'},
#   'DataSet': {'@xmlns': 'http://dataservices.imf.org/compact/IFS',
#    'Series': [{'@FREQ': 'A',
#      '@REF_AREA': 'HK',
#      '@INDICATOR': 'PCPI_IX',
#      '@UNIT_MULT': '0',
#      '@BASE_YEAR': '2010=100',
#      '@TIME_FORMAT': 'P1Y',
#      'Obs': [{'@TIME_PERIOD': '2017', '@OBS_VALUE': '127.768157278191'},
#       {'@TIME_PERIOD': '2018', '@OBS_VALUE': '130.844453499032'},
#       {'@TIME_PERIOD': '2019', '@OBS_VALUE': '134.593052867475'}]},
#     {'@FREQ': 'A',
#      '@REF_AREA': 'CZ',
#      '@INDICATOR': 'PCPI_IX',
#      '@UNIT_MULT': '0',
#      '@BASE_YEAR': '2010=100',
#      '@TIME_FORMAT': 'P1Y',
#      'Obs': [{'@TIME_PERIOD': '2017', '@OBS_VALUE': '110.867228095323'},
#       {'@TIME_PERIOD': '2018', '@OBS_VALUE': '113.250313563877'},
#       {'@TIME_PERIOD': '2019', '@OBS_VALUE': '116.47554201756'}]},
#     {'@FREQ': 'A',
#      '@REF_AREA': 'RO',
#      '@INDICATOR': 'PCPI_IX',
#      '@UNIT_MULT': '0',
#      '@BASE_YEAR': '2010=100',
#      '@TIME_FORMAT': 'P1Y',
#      'Obs': [{'@TIME_PERIOD': '2017', '@OBS_VALUE': '113.946361611816'},
#       {'@TIME_PERIOD': '2018', '@OBS_VALUE': '119.216932828292'}]},
#     {'@FREQ': 'A',
#      '@REF_AREA': 'KI',
#      '@INDICATOR': 'PCPI_IX',
#      '@UNIT_MULT': '0',
#      '@BASE_YEAR': '2010=100',
#      '@TIME_FORMAT': 'P1Y'},
#     {'@FREQ': 'A',
#      '@REF_AREA': 'ET',
#      '@INDICATOR': 'PCPI_IX',
#      '@UNIT_MULT': '0',
#      '@BASE_YEAR': '2010=100',
#      '@TIME_FORMAT': 'P1Y',
#      'Obs': {'@TIME_PERIOD': '2017', '@OBS_VALUE': '249.09053267292'}},
#     {'@FREQ': 'A',
#      '@REF_AREA': 'CY',
#      '@INDICATOR': 'PCPI_IX',
#      '@UNIT_MULT': '0',
#      '@BASE_YEAR': '2010=100',
#      '@TIME_FORMAT': 'P1Y',
#      'Obs': [{'@TIME_PERIOD': '2017', '@OBS_VALUE': '100.807886777964'},
#       {'@TIME_PERIOD': '2018', '@OBS_VALUE': '102.254975116847'}]},
#     {'@FREQ': 'A',
#      '@REF_AREA': 'AL',
#      '@INDICATOR': 'PCPI_IX',
#      '@UNIT_MULT': '0',
#      '@BASE_YEAR': '2010=100',
#      '@TIME_FORMAT': 'P1Y',
#      'Obs': [{'@TIME_PERIOD': '2017', '@OBS_VALUE': '115.059269640307'},
#       {'@TIME_PERIOD': '2018', '@OBS_VALUE': '117.392740239273'},
#       {'@TIME_PERIOD': '2019', '@OBS_VALUE': '119.049258384381'}]},
#     {'@FREQ': 'A',
#      '@REF_AREA': 'HU',
#      '@INDICATOR': 'PCPI_IX',
#      '@UNIT_MULT': '0',
#      '@BASE_YEAR': '2010=100',
#      '@TIME_FORMAT': 'P1Y',
#      'Obs': [{'@TIME_PERIOD': '2017', '@OBS_VALUE': '114.450017176228'},
#       {'@TIME_PERIOD': '2018', '@OBS_VALUE': '117.712126417039'},
#       {'@TIME_PERIOD': '2019', '@OBS_VALUE': '121.64204740639'}]},
#     {'@FREQ': 'A',
#      '@REF_AREA': 'MW',
#      '@INDICATOR': 'PCPI_IX',
#      '@UNIT_MULT': '0',
#      '@BASE_YEAR': '2010=100',
#      '@TIME_FORMAT': 'P1Y',
#      'Obs': [{'@TIME_PERIOD': '2017', '@OBS_VALUE': '340.242124547702'},
#       {'@TIME_PERIOD': '2018', '@OBS_VALUE': '382.500802418103'}]},
#     {'@FREQ': 'A',
#      '@REF_AREA': 'BW',
#      '@INDICATOR': 'PCPI_IX',
#      '@UNIT_MULT': '0',
#      '@BASE_YEAR': '2010=100',
#      '@TIME_FORMAT': 'P1Y',
#      'Obs': [{'@TIME_PERIOD': '2017', '@OBS_VALUE': '141.143033956383'},
#       {'@TIME_PERIOD': '2018', '@OBS_VALUE': '145.713267399351'}]},
#     {'@FREQ': 'A',
#      '@REF_AREA': 'KE',
#      '@INDICATOR': 'PCPI_IX',
#      '@UNIT_MULT': '0',
#      '@BASE_YEAR': '2010=100',
#      '@TIME_FORMAT': 'P1Y',
#      'Obs': [{'@TIME_PERIOD': '2017', '@OBS_VALUE': '172.428238576216'},
#       {'@TIME_PERIOD': '2018', '@OBS_VALUE': '180.514812183022'}]},
#     {'@FREQ': 'A',
#      '@REF_AREA': 'KG',
#      '@INDICATOR': 'PCPI_IX',
#      '@UNIT_MULT': '0',
#      '@BASE_YEAR': '2010=100',
#      '@TIME_FORMAT': 'P1Y',
#      'Obs': [{'@TIME_PERIOD': '2017', '@OBS_VALUE': '151.592593591367'},
#       {'@TIME_PERIOD': '2018', '@OBS_VALUE': '153.931154097371'}]},
#     {'@FREQ': 'A',
#      '@REF_AREA': 'SV',
#      '@INDICATOR': 'PCPI_IX',
#      '@UNIT_MULT': '0',
#      '@BASE_YEAR': '2010=100',
#      '@TIME_FORMAT': 'P1Y',
#      'Obs': [{'@TIME_PERIOD': '2017', '@OBS_VALUE': '109.945860865915'},
#       {'@TIME_PERIOD': '2018', '@OBS_VALUE': '111.144633577092'},
#       {'@TIME_PERIOD': '2019', '@OBS_VALUE': '111.229895971862'}]},
#     {'@FREQ': 'A',
#      '@REF_AREA': 'PL',
#      '@INDICATOR': 'PCPI_IX',
#      '@UNIT_MULT': '0',
#      '@BASE_YEAR': '2010=100',
#      '@TIME_FORMAT': 'P1Y',
#      'Obs': [{'@TIME_PERIOD': '2017', '@OBS_VALUE': '109.637670529558'},
#       {'@TIME_PERIOD': '2018', '@OBS_VALUE': '111.625348393722'},
#       {'@TIME_PERIOD': '2019', '@OBS_VALUE': '114.111779375092'}]},
#     {'@FREQ': 'A',
#      '@REF_AREA': 'TN',
#      '@INDICATOR': 'PCPI_IX',
#      '@UNIT_MULT': '0',
#      '@BASE_YEAR': '2010=100',
#      '@TIME_FORMAT': 'P1Y',
#      'Obs': [{'@TIME_PERIOD': '2017', '@OBS_VALUE': '135.633145958134'},
#       {'@TIME_PERIOD': '2018', '@OBS_VALUE': '145.544662556429'}]},
#     {'@FREQ': 'A',
#      '@REF_AREA': '7A',
#      '@INDICATOR': 'PCPI_IX',
#      '@UNIT_MULT': '0',
#      '@TIME_FORMAT': 'P1Y'},
#     {'@FREQ': 'A',
#      '@REF_AREA': 'JP',
#      '@INDICATOR': 'PCPI_IX',
#      '@UNIT_MULT': '0',
#      '@BASE_YEAR': '2010=100',
#      '@TIME_FORMAT': 'P1Y',
#      'Obs': [{'@TIME_PERIOD': '2017', '@OBS_VALUE': '103.962703962704'},
#       {'@TIME_PERIOD': '2018', '@OBS_VALUE': '104.981438314772'},
#       {'@TIME_PERIOD': '2019', '@OBS_VALUE': '105.482172148839'}]},
#     {'@FREQ': 'A',
#      '@REF_AREA': 'SE',
#      '@INDICATOR': 'PCPI_IX',
#      '@UNIT_MULT': '0',
#      '@BASE_YEAR': '2010=100',
#      '@TIME_FORMAT': 'P1Y',
#      'Obs': [{'@TIME_PERIOD': '2017', '@OBS_VALUE': '106.491774734342'},
#       {'@TIME_PERIOD': '2018', '@OBS_VALUE': '108.572129146727'},
#       {'@TIME_PERIOD': '2019', '@OBS_VALUE': '110.509219846432'}]},
#     {'@FREQ': 'A',
#      '@REF_AREA': 'MG',
#      '@INDICATOR': 'PCPI_IX',
#      '@UNIT_MULT': '0',
#      '@BASE_YEAR': '2010=100',
#      '@TIME_FORMAT': 'P1Y',
#      'Obs': [{'@TIME_PERIOD': '2017', '@OBS_VALUE': '160.696257657837'},
#       {'@TIME_PERIOD': '2018', '@OBS_VALUE': '174.512854781089'}]},
#     {'@FREQ': 'A',
#      '@REF_AREA': 'DK',
#      '@INDICATOR': 'PCPI_IX',
#      '@UNIT_MULT': '0',
#      '@BASE_YEAR': '2010=100',
#      '@TIME_FORMAT': 'P1Y',
#      'Obs': [{'@TIME_PERIOD': '2017', '@OBS_VALUE': '108.633157753772'},
#       {'@TIME_PERIOD': '2018', '@OBS_VALUE': '109.517007410053'},
#       {'@TIME_PERIOD': '2019', '@OBS_VALUE': '110.347290420498'}]},
#     {'@FREQ': 'A',
#      '@REF_AREA': 'OM',
#      '@INDICATOR': 'PCPI_IX',
#      '@UNIT_MULT': '0',
#      '@BASE_YEAR': '2010=100',
#      '@TIME_FORMAT': 'P1Y',
#      'Obs': [{'@TIME_PERIOD': '2017', '@OBS_VALUE': '112.387122104437'},
#       {'@TIME_PERIOD': '2018', '@OBS_VALUE': '113.377592176179'}]},
#     {'@FREQ': 'A',
#      '@REF_AREA': 'AN',
#      '@INDICATOR': 'PCPI_IX',
#      '@UNIT_MULT': '0',
#      '@TIME_FORMAT': 'P1Y'},
#     {'@FREQ': 'A',
#      '@REF_AREA': 'LU',
#      '@INDICATOR': 'PCPI_IX',
#      '@UNIT_MULT': '0',
#      '@BASE_YEAR': '2010=100',
#      '@TIME_FORMAT': 'P1Y',
#      'Obs': [{'@TIME_PERIOD': '2017', '@OBS_VALUE': '111.413231413231'},
#       {'@TIME_PERIOD': '2018', '@OBS_VALUE': '113.115843115843'},
#       {'@TIME_PERIOD': '2019', '@OBS_VALUE': '115.087815087815'}]},
#     {'@FREQ': 'A',
#      '@REF_AREA': 'KN',
#      '@INDICATOR': 'PCPI_IX',
#      '@UNIT_MULT': '0',
#      '@BASE_YEAR': '2010=100',
#      '@TIME_FORMAT': 'P1Y',
#      'Obs': [{'@TIME_PERIOD': '2017', '@OBS_VALUE': '105.661274976213'},
#       {'@TIME_PERIOD': '2018', '@OBS_VALUE': '104.565438498638'}]},
#     {'@FREQ': 'A',
#      '@REF_AREA': 'GY',
#      '@INDICATOR': 'PCPI_IX',
#      '@UNIT_MULT': '0',
#      '@BASE_YEAR': '2010=100',
#      '@TIME_FORMAT': 'P1Y',
#      'Obs': [{'@TIME_PERIOD': '2017', '@OBS_VALUE': '112.374289819108'},
#       {'@TIME_PERIOD': '2018', '@OBS_VALUE': '113.815875399987'}]},
#     {'@FREQ': 'A',
#      '@REF_AREA': 'MV',
#      '@INDICATOR': 'PCPI_IX',
#      '@UNIT_MULT': '0',
#      '@BASE_YEAR': '2010=100',
#      '@TIME_FORMAT': 'P1Y',
#      'Obs': [{'@TIME_PERIOD': '2017', '@OBS_VALUE': '136.445336799763'},
#       {'@TIME_PERIOD': '2018', '@OBS_VALUE': '136.263355031904'}]},
#     {'@FREQ': 'A',
#      '@REF_AREA': 'BH',
#      '@INDICATOR': 'PCPI_IX',
#      '@UNIT_MULT': '0',
#      '@BASE_YEAR': '2010=100',
#      '@TIME_FORMAT': 'P1Y',
#      'Obs': [{'@TIME_PERIOD': '2017', '@OBS_VALUE': '115.189591078067'},
#       {'@TIME_PERIOD': '2018', '@OBS_VALUE': '117.591078066915'}]},
#     {'@FREQ': 'A',
#      '@REF_AREA': 'GN',
#      '@INDICATOR': 'PCPI_IX',
#      '@UNIT_MULT': '0',
#      '@BASE_YEAR': '2010=100',
#      '@TIME_FORMAT': 'P1Y',
#      'Obs': [{'@TIME_PERIOD': '2017', '@OBS_VALUE': '218.710407349519'},
#       {'@TIME_PERIOD': '2018', '@OBS_VALUE': '240.200984328988'}]},
#     {'@FREQ': 'A',
#      '@REF_AREA': 'LV',
#      '@INDICATOR': 'PCPI_IX',
#      '@UNIT_MULT': '0',
#      '@BASE_YEAR': '2010=100',
#      '@TIME_FORMAT': 'P1Y',
#      'Obs': [{'@TIME_PERIOD': '2017', '@OBS_VALUE': '110.852001659202'},
#       {'@TIME_PERIOD': '2018', '@OBS_VALUE': '113.661494917447'},
#       {'@TIME_PERIOD': '2019', '@OBS_VALUE': '116.856984643273'}]},
#     {'@FREQ': 'A',
#      '@REF_AREA': 'IQ',
#      '@INDICATOR': 'PCPI_IX',
#      '@UNIT_MULT': '0',
#      '@BASE_YEAR': '2010=100',
#      '@TIME_FORMAT': 'P1Y',
#      'Obs': [{'@TIME_PERIOD': '2017', '@OBS_VALUE': '119.418381179572'},
#       {'@TIME_PERIOD': '2018', '@OBS_VALUE': '119.857173857442'}]},
#     {'@FREQ': 'A',
#      '@REF_AREA': 'SN',
#      '@INDICATOR': 'PCPI_IX',
#      '@UNIT_MULT': '0',
#      '@BASE_YEAR': '2010=100',
#      '@TIME_FORMAT': 'P1Y',
#      'Obs': [{'@TIME_PERIOD': '2017', '@OBS_VALUE': '106.870560070658'},
#       {'@TIME_PERIOD': '2018', '@OBS_VALUE': '107.363218008605'}]},
#     {'@FREQ': 'A',
#      '@REF_AREA': 'BF',
#      '@INDICATOR': 'PCPI_IX',
#      '@UNIT_MULT': '0',
#      '@BASE_YEAR': '2010=100',
#      '@TIME_FORMAT': 'P1Y',
#      'Obs': [{'@TIME_PERIOD': '2017', '@OBS_VALUE': '108.122350020369'},
#       {'@TIME_PERIOD': '2018', '@OBS_VALUE': '110.138236726718'},
#       {'@TIME_PERIOD': '2019', '@OBS_VALUE': '106.578776314878'}]},
#     {'@FREQ': 'A',
#      '@REF_AREA': 'AF',
#      '@INDICATOR': 'PCPI_IX',
#      '@UNIT_MULT': '0',
#      '@BASE_YEAR': '2010=100',
#      '@TIME_FORMAT': 'P1Y',
#      'Obs': {'@TIME_PERIOD': '2017', '@OBS_VALUE': '145.610741438593'}},
#     {'@FREQ': 'A',
#      '@REF_AREA': 'LB',
#      '@INDICATOR': 'PCPI_IX',
#      '@UNIT_MULT': '0',
#      '@BASE_YEAR': '2010=100',
#      '@TIME_FORMAT': 'P1Y',
#      'Obs': [{'@TIME_PERIOD': '2017', '@OBS_VALUE': '118.999307190905'},
#       {'@TIME_PERIOD': '2018', '@OBS_VALUE': '126.230882092859'}]},
#     {'@FREQ': 'A',
#      '@REF_AREA': 'CH',
#      '@INDICATOR': 'PCPI_IX',
#      '@UNIT_MULT': '0',
#      '@BASE_YEAR': '2010=100',
#      '@TIME_FORMAT': 'P1Y',
#      'Obs': [{'@TIME_PERIOD': '2017', '@OBS_VALUE': '98.2668620110493'},
#       {'@TIME_PERIOD': '2018', '@OBS_VALUE': '99.1869477125836'},
#       {'@TIME_PERIOD': '2019', '@OBS_VALUE': '99.5469130202278'}]},
#     {'@FREQ': 'A',
#      '@REF_AREA': 'SG',
#      '@INDICATOR': 'PCPI_IX',
#      '@UNIT_MULT': '0',
#      '@BASE_YEAR': '2010=100',
#      '@TIME_FORMAT': 'P1Y',
#      'Obs': [{'@TIME_PERIOD': '2017', '@OBS_VALUE': '113.266146321473'},
#       {'@TIME_PERIOD': '2018', '@OBS_VALUE': '113.762839460733'},
#       {'@TIME_PERIOD': '2019', '@OBS_VALUE': '114.405903400963'}]},
#     {'@FREQ': 'A',
#      '@REF_AREA': 'LA',
#      '@INDICATOR': 'PCPI_IX',
#      '@UNIT_MULT': '0',
#      '@BASE_YEAR': '2010=100',
#      '@TIME_FORMAT': 'P1Y',
#      'Obs': [{'@TIME_PERIOD': '2017', '@OBS_VALUE': '128.86810928206'},
#       {'@TIME_PERIOD': '2018', '@OBS_VALUE': '131.496856408277'}]},
#     {'@FREQ': 'A',
#      '@REF_AREA': 'CN',
#      '@INDICATOR': 'PCPI_IX',
#      '@UNIT_MULT': '0',
#      '@BASE_YEAR': '2010=100',
#      '@TIME_FORMAT': 'P1Y',
#      'Obs': [{'@TIME_PERIOD': '2017', '@OBS_VALUE': '119.088051569694'},
#       {'@TIME_PERIOD': '2018', '@OBS_VALUE': '121.558877247618'},
#       {'@TIME_PERIOD': '2019', '@OBS_VALUE': '125.083155733959'}]},
#     {'@FREQ': 'A',
#      '@REF_AREA': 'FI',
#      '@INDICATOR': 'PCPI_IX',
#      '@UNIT_MULT': '0',
#      '@BASE_YEAR': '2010=100',
#      '@TIME_FORMAT': 'P1Y',
#      'Obs': [{'@TIME_PERIOD': '2017', '@OBS_VALUE': '110.000779878603'},
#       {'@TIME_PERIOD': '2018', '@OBS_VALUE': '111.192991413593'},
#       {'@TIME_PERIOD': '2019', '@OBS_VALUE': '112.331712088838'}]},
#     {'@FREQ': 'A',
#      '@REF_AREA': 'AI',
#      '@INDICATOR': 'PCPI_IX',
#      '@UNIT_MULT': '0',
#      '@TIME_FORMAT': 'P1Y'},
#     {'@FREQ': 'A',
#      '@REF_AREA': 'LT',
#      '@INDICATOR': 'PCPI_IX',
#      '@UNIT_MULT': '0',
#      '@BASE_YEAR': '2010=100',
#      '@TIME_FORMAT': 'P1Y',
#      'Obs': [{'@TIME_PERIOD': '2017', '@OBS_VALUE': '112.642489751195'},
#       {'@TIME_PERIOD': '2018', '@OBS_VALUE': '115.681502787888'},
#       {'@TIME_PERIOD': '2019', '@OBS_VALUE': '118.382098321258'}]},
#     {'@FREQ': 'A',
#      '@REF_AREA': 'BT',
#      '@INDICATOR': 'PCPI_IX',
#      '@UNIT_MULT': '0',
#      '@BASE_YEAR': '2010=100',
#      '@TIME_FORMAT': 'P1Y',
#      'Obs': [{'@TIME_PERIOD': '2017', '@OBS_VALUE': '158.43097935229'},
#       {'@TIME_PERIOD': '2018', '@OBS_VALUE': '162.746286170163'}]},
#     {'@FREQ': 'A',
#      '@REF_AREA': 'RW',
#      '@INDICATOR': 'PCPI_IX',
#      '@UNIT_MULT': '0',
#      '@BASE_YEAR': '2010=100',
#      '@TIME_FORMAT': 'P1Y',
#      'Obs': [{'@TIME_PERIOD': '2017', '@OBS_VALUE': '146.64111357676'},
#       {'@TIME_PERIOD': '2018', '@OBS_VALUE': '146.187210006052'},
#       {'@TIME_PERIOD': '2019', '@OBS_VALUE': '151.089368569699'}]},
#     {'@FREQ': 'A',
#      '@REF_AREA': 'BD',
#      '@INDICATOR': 'PCPI_IX',
#      '@UNIT_MULT': '0',
#      '@BASE_YEAR': '2010=100',
#      '@TIME_FORMAT': 'P1Y',
#      'Obs': [{'@TIME_PERIOD': '2017', '@OBS_VALUE': '161.226458913586'},
#       {'@TIME_PERIOD': '2018', '@OBS_VALUE': '170.164243384102'}]},
#     {'@FREQ': 'A',
#      '@REF_AREA': 'MT',
#      '@INDICATOR': 'PCPI_IX',
#      '@UNIT_MULT': '0',
#      '@BASE_YEAR': '2010=100',
#      '@TIME_FORMAT': 'P1Y',
#      'Obs': [{'@TIME_PERIOD': '2017', '@OBS_VALUE': '110.342046800347'},
#       {'@TIME_PERIOD': '2018', '@OBS_VALUE': '111.619613085975'},
#       {'@TIME_PERIOD': '2019', '@OBS_VALUE': '113.452474124359'}]},
#     {'@FREQ': 'A',
#      '@REF_AREA': 'MA',
#      '@INDICATOR': 'PCPI_IX',
#      '@UNIT_MULT': '0',
#      '@BASE_YEAR': '2010=100',
#      '@TIME_FORMAT': 'P1Y',
#      'Obs': [{'@TIME_PERIOD': '2017', '@OBS_VALUE': '108.769502728461'},
#       {'@TIME_PERIOD': '2018', '@OBS_VALUE': '110
},
#    {'@TIME_PERIOD': '2018', '@OBS_VALUE': '198.633984205053'}]},
#  {'@FREQ': 'A',
#   '@REF_AREA': 'XR29',
#   '@INDICATOR': 'PCPI_IX',
#   '@UNIT_MULT': '0',
#   '@BASE_YEAR': '2010=100',
#   '@TIME_FORMAT': 'P1Y',
#   'Obs': [{'@TIME_PERIOD': '2017', '@OBS_VALUE': '110.143838690462'},
#    {'@TIME_PERIOD': '2018', '@OBS_VALUE': '112.035502009006'}]}]

# %%
data[0] # a dict for the first value
# Out:
# {'@FREQ': 'A',
#  '@REF_AREA': 'HK',
#  '@INDICATOR': 'PCPI_IX',
#  '@UNIT_MULT': '0',
#  '@BASE_YEAR': '2010=100',
#  '@TIME_FORMAT': 'P1Y',
#  'Obs': [{'@TIME_PERIOD': '2018', '@OBS_VALUE': '130.844453499032'},
#   {'@TIME_PERIOD': '2019', '@OBS_VALUE': '134.593052867475'}]}

# %%
data[1]['Obs'][0]['@TIME_PERIOD']
# Out:
# '2018'

# %%
list(
    zip([data[0]['Obs'][0]['@TIME_PERIOD']],
        [data[0]['Obs'][0]['@OBS_VALUE']])
)
# Out:
# [('2018', '130.844453499032')]

# %%
s['Obs']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-158-4b7adafc6e75> in <module>
# ----> 1 s['Obs']
#
# KeyError: 'Obs'

# %%
areas = [data[i]['@REF_AREA'] for i in range(len(data))]
areas[:10]
# Out:
# ['HK', 'CZ', 'RO', 'KI', 'ET', 'CY', 'AL', 'HU', 'MW', 'BW']

# %%
{s['@REF_AREA'] for s in data}
# Out:
# {'1C_440',
#  '1C_473',
#  '1C_903',
#  '7A',
#  'A10',
#  'AE',
#  'AF',
#  'AG',
#  'AI',
#  'AL',
#  'AM',
#  'AN',
#  'AO',
#  'AT',
#  'AU',
#  'AW',
#  'AZ',
#  'BA',
#  'BB',
#  'BD',
#  'BE',
#  'BF',
#  'BG',
#  'BH',
#  'BI',
#  'BJ',
#  'BN',
#  'BO',
#  'BR',
#  'BS',
#  'BT',
#  'BW',
#  'BY',
#  'BZ',
#  'CA',
#  'CD',
#  'CF',
#  'CG',
#  'CH',
#  'CI',
#  'CL',
#  'CM',
#  'CN',
#  'CO',
#  'CR',
#  'CSH',
#  'CV',
#  'CW',
#  'CY',
#  'CZ',
#  'DE',
#  'DJ',
#  'DK',
#  'DM',
#  'DO',
#  'DZ',
#  'E1',
#  'EC',
#  'EE',
#  'EG',
#  'ES',
#  'ET',
#  'F6',
#  'FI',
#  'FJ',
#  'FM',
#  'FR',
#  'GA',
#  'GB',
#  'GD',
#  'GE',
#  'GH',
#  'GM',
#  'GN',
#  'GP',
#  'GQ',
#  'GR',
#  'GT',
#  'GW',
#  'GY',
#  'HK',
#  'HN',
#  'HR',
#  'HT',
#  'HU',
#  'ID',
#  'IE',
#  'IL',
#  'IN',
#  'IQ',
#  'IR',
#  'IS',
#  'IT',
#  'JM',
#  'JO',
#  'JP',
#  'KE',
#  'KG',
#  'KH',
#  'KI',
#  'KM',
#  'KN',
#  'KR',
#  'KW',
#  'KY',
#  'KZ',
#  'LA',
#  'LB',
#  'LC',
#  'LK',
#  'LR',
#  'LS',
#  'LT',
#  'LU',
#  'LV',
#  'LY',
#  'MA',
#  'MD',
#  'ME',
#  'MG',
#  'MK',
#  'ML',
#  'MM',
#  'MN',
#  'MO',
#  'MQ',
#  'MR',
#  'MS',
#  'MT',
#  'MU',
#  'MV',
#  'MW',
#  'MX',
#  'MY',
#  'MZ',
#  'NA',
#  'NC',
#  'NE',
#  'NG',
#  'NI',
#  'NL',
#  'NO',
#  'NP',
#  'NZ',
#  'OM',
#  'PA',
#  'PE',
#  'PG',
#  'PH',
#  'PK',
#  'PL',
#  'PS',
#  'PT',
#  'PW',
#  'PY',
#  'QA',
#  'R14',
#  'RO',
#  'RS',
#  'RU',
#  'RW',
#  'SA',
#  'SB',
#  'SC',
#  'SD',
#  'SE',
#  'SG',
#  'SI',
#  'SK',
#  'SL',
#  'SM',
#  'SN',
#  'SR',
#  'SS',
#  'ST',
#  'SV',
#  'SX',
#  'SY',
#  'SZ',
#  'TD',
#  'TG',
#  'TH',
#  'TJ',
#  'TL',
#  'TN',
#  'TO',
#  'TR',
#  'TT',
#  'TW',
#  'TZ',
#  'UA',
#  'UG',
#  'US',
#  'UY',
#  'VC',
#  'VE',
#  'VN',
#  'VU',
#  'W00',
#  'WS',
#  'XK',
#  'XR29',
#  'XR43',
#  'XS25',
#  'YE',
#  'YUC',
#  'ZA',
#  'ZM',
#  'ZW'}

# %%
data[0].items()
# Out:
# dict_items([('@FREQ', 'A'), ('@REF_AREA', 'HK'), ('@INDICATOR', 'PCPI_IX'), ('@UNIT_MULT', '0'), ('@BASE_YEAR', '2010=100'), ('@TIME_FORMAT', 'P1Y'), ('Obs', [{'@TIME_PERIOD': '2018', '@OBS_VALUE': '130.844453499032'}, {'@TIME_PERIOD': '2019', '@OBS_VALUE': '134.593052867475'}])])

# %%
data[0].keys()
# Out:
# dict_keys(['@FREQ', '@REF_AREA', '@INDICATOR', '@UNIT_MULT', '@BASE_YEAR', '@TIME_FORMAT', 'Obs'])

# %%
data[0].values()
# Out:
# dict_values(['A', 'HK', 'PCPI_IX', '0', '2010=100', 'P1Y', [{'@TIME_PERIOD': '2018', '@OBS_VALUE': '130.844453499032'}, {'@TIME_PERIOD': '2019', '@OBS_VALUE': '134.593052867475'}]])

# %%
[i for i in data[0].keys()]
# Out:
# ['@FREQ',
#  '@REF_AREA',
#  '@INDICATOR',
#  '@UNIT_MULT',
#  '@BASE_YEAR',
#  '@TIME_FORMAT',
#  'Obs']

# %%
[i for i in data[0].values()]
# Out:
# ['A',
#  'HK',
#  'PCPI_IX',
#  '0',
#  '2010=100',
#  'P1Y',
#  [{'@TIME_PERIOD': '2018', '@OBS_VALUE': '130.844453499032'},
#   {'@TIME_PERIOD': '2019', '@OBS_VALUE': '134.593052867475'}]]

# %%
l = np.array([])
print(l)
np.append(l,[1,2],axis=1)
print(l)
# Out:
# []
# ---------------------------------------------------------------------------
# AxisError                                 Traceback (most recent call last)
# <ipython-input-314-50148672ba47> in <module>
#       1 l = np.array([])
#       2 print(l)
# ----> 3 np.append(l,[1,2],axis=1)
#       4 print(l)
#
# <__array_function__ internals> in append(*args, **kwargs)
#
# ~/anaconda3/envs/geopandas/lib/python3.7/site-packages/numpy/lib/function_base.py in append(arr, values, axis)
#    4691         values = ravel(values)
#    4692         axis = arr.ndim-1
# -> 4693     return concatenate((arr, values), axis=axis)
#    4694
#    4695
#
# <__array_function__ internals> in concatenate(*args, **kwargs)
#
# AxisError: axis 1 is out of bounds for array of dimension 1

# %%
data[0]['Obs'][0]['@OBS_VALUE']
# Out:
# '127.768157278191'

# %%
l = []
years = []
price_index = []
# some values are lists and other are dicts
for i in range(len(data)):
    a = list(data[i].items())[-1][1]
    b = list(data[0].items())[-1][1][0]['@OBS_VALUE']
    #print (isinstance(a,list))
    #print(list(data[i].items())[-1][1])
    #print(len(a))
    #print(type(list(data[i].items())[-1][1]))
    if isinstance(a,list):
        l.append(a[0]['@TIME_PERIOD'])
        price_index.append(data[i]['Obs'][0]['@OBS_VALUE'])
    else:
        l.append(np.nan)
        price_index.append(np.nan)
price_index
# Out:
# ['127.768157278191',
#  '110.867228095323',
#  '113.946361611816',
#  nan,
#  nan,
#  '100.807886777964',
#  '115.059269640307',
#  '114.450017176228',
#  '340.242124547702',
#  '141.143033956383',
#  '172.428238576216',
#  '151.592593591367',
#  '109.945860865915',
#  '109.637670529558',
#  '135.633145958134',
#  nan,
#  '103.962703962704',
#  '106.491774734342',
#  '160.696257657837',
#  '108.633157753772',
#  '112.387122104437',
#  nan,
#  '111.413231413231',
#  '105.661274976213',
#  '112.374289819108',
#  '136.445336799763',
#  '115.189591078067',
#  '218.710407349519',
#  '110.852001659202',
#  '119.418381179572',
#  '106.870560070658',
#  '108.122350020369',
#  nan,
#  '118.999307190905',
#  '98.2668620110493',
#  '113.266146321473',
#  '128.86810928206',
#  '119.088051569694',
#  '110.000779878603',
#  nan,
#  '112.642489751195',
#  '158.43097935229',
#  '146.64111357676',
#  '161.226458913586',
#  '110.342046800347',
#  '108.769502728461',
#  nan,
#  nan,
#  '105.079585978951',
#  '231.094115427901',
#  '121.577794043312',
#  nan,
#  '112.450169287899',
#  '107.402110095793',
#  nan,
#  '125.41634177371',
#  '124.571541363331',
#  '110.881574765532',
#  '118.017501678462',
#  '107.363994273443',
#  '155.668786230018',
#  nan,
#  '111.984831139096',
#  '120.211352458706',
#  '188.682529221908',
#  '113.050800144607',
#  '110.982350206884',
#  '136.09909107849',
#  '115.455324823776',
#  '124.207629297982',
#  '142.182412273917',
#  '106.864453008147',
#  '142.402953510879',
#  nan,
#  '150.749350064901',
#  '114.583313019794',
#  '108.901467247481',
#  nan,
#  '144.606264199701',
#  '155.798794620082',
#  nan,
#  nan,
#  '147.156465910385',
#  nan,
#  '131.87726913518',
#  nan,
#  '106.569335074026',
#  nan,
#  '111.685167528351',
#  '124.180858333333',
#  '174.96870328849',
#  '109.590332058318',
#  nan,
#  nan,
#  nan,
#  '159.396200425506',
#  '138.053432225838',
#  '147.08785819643',
#  '125.357593401262',
#  '113.128902605325',
#  '175.782696759259',
#  '156.912294705271',
#  '168.171663863806',
#  '111.503213533868',
#  nan,
#  nan,
#  '214.232119297381',
#  '128.055246473499',
#  '123.094557177785',
#  nan,
#  nan,
#  '170.800588522644',
#  '113.999736749152',
#  '232.256486631321',
#  '114.943591640466',
#  '140.323978776513',
#  '111.286809151122',
#  '107.935364262011',
#  '114.55071939191',
#  '99.1054142101762',
#  '159.829464708669',
#  '138.665453442524',
#  '164.700179755387',
#  '149.472332583468',
#  '107.174776564052',
#  '108.714901774357',
#  '153.842495547244',
#  '108.375335054149',
#  '109.35246347718',
#  '180.579023030835',
#  '101.991968327769',
#  nan,
#  nan,
#  '171.587985799762',
#  '108.037798261528',
#  '130.197802476747',
#  '115.686784599376',
#  nan,
#  nan,
#  nan,
#  '101.059873345855',
#  nan,
#  '109.166705134988',
#  '108.965993300498',
#  '143.73138369889',
#  '142.666698206189',
#  nan,
#  '107.938957188495',
#  '124.24507403521',
#  '115.857023336953',
#  '124.09140868848',
#  '102.85158612695',
#  '110.651578737121',
#  '121.189371257485',
#  '102.85222335235',
#  '128.508380599882',
#  '119.337275098544',
#  nan,
#  '112.451978676858',
#  nan,
#  '141.641665779103',
#  '124.894797245601',
#  '146.053721453082',
#  '142.384203185789',
#  nan,
#  '106.380697050938',
#  nan,
#  '180.949079423773',
#  '110.915833333333',
#  '151.384955794723',
#  nan,
#  '459.025218055968',
#  '121.956960656067',
#  '175.03783564472',
#  '134.610557401255',
#  '155.127594097827',
#  '113.360041214069',
#  '113.302920986271',
#  '123.458180275621',
#  nan,
#  nan,
#  '116.215753245397',
#  nan,
#  '111.384588808318',
#  '146.029865379932',
#  '119.605065822363',
#  nan,
#  '124.557631780803',
#  '174.800034255374',
#  '235.299204427534',
#  '132.838100804773',
#  '125.566544829069',
#  nan,
#  '108.883878892078',
#  '114.242951414668',
#  '280.763277338802',
#  '112.411557302308',
#  '111.042062834942',
#  nan,
#  '132.024300273437',
#  '141.312804619955',
#  '189.653048452383',
#  '131.530050522948',
#  '149.725471738036',
#  '165.351837584771',
#  '182.982964247109',
#  '139.426093893292',
#  '181.661355082963',
#  '110.143838690462']

# %%
dict(data[1].items())['Obs'][1]
# Out:
# {'@TIME_PERIOD': '2019', '@OBS_VALUE': '116.47554201756'}

# %%
dict(zip([i for i in data[0].keys()],[i for i in data[0].values()]))['Obs'][0]['@OBS_VALUE']
# Out:
# '130.844453499032'

# %%
[data[i]['Obs'][0]['@OBS_VALUE'] for i in range(len(data))]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-173-662292249592> in <module>
# ----> 1 [data[i]['Obs'][0]['@OBS_VALUE'] for i in range(len(data))]
#
# <ipython-input-173-662292249592> in <listcomp>(.0)
# ----> 1 [data[i]['Obs'][0]['@OBS_VALUE'] for i in range(len(data))]
#
# KeyError: 0

# %%
data = r['CompactData']['DataSet']['Series']

# %%
# Create pandas dataframe, column = country, row = obs
df = pd.DataFrame({s['@REF_AREA']: # Each country/area
                   {i['@TIME_PERIOD']: float(i['@OBS_VALUE']) 
                    for i in s['Obs']} for s in data})

df
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-84-27ebd9cc301e> in <module>
#       2 df = pd.DataFrame({s['@REF_AREA']: # Each country/area
#       3                    {i['@TIME_PERIOD']: float(i['@OBS_VALUE'])
# ----> 4                     for i in s['Obs']} for s in data})
#       5
#       6 df
#
# <ipython-input-84-27ebd9cc301e> in <dictcomp>(.0)
#       2 df = pd.DataFrame({s['@REF_AREA']: # Each country/area
#       3                    {i['@TIME_PERIOD']: float(i['@OBS_VALUE'])
# ----> 4                     for i in s['Obs']} for s in data})
#       5
#       6 df
#
# <ipython-input-84-27ebd9cc301e> in <dictcomp>(.0)
#       2 df = pd.DataFrame({s['@REF_AREA']: # Each country/area
#       3                    {i['@TIME_PERIOD']: float(i['@OBS_VALUE'])
# ----> 4                     for i in s['Obs']} for s in data})
#       5
#       6 df
#
# TypeError: string indices must be integers

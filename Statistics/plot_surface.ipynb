# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
X = [1, 2, 3]
Y = [1, 2, 3]
print(X)
print(Y)
# Out:
# [1, 2, 3]
# [1, 2, 3]

# %%
X, Y = np.meshgrid(X, Y)
X
# Out:
# array([[1, 2, 3],
#        [1, 2, 3],
#        [1, 2, 3]])

# %%
Y
# Out:
# array([[1, 1, 1],
#        [2, 2, 2],
#        [3, 3, 3]])

# %%
print(X)
# Out:
# [[1 2 3]
#  [1 2 3]
#  [1 2 3]]

# %%
Z = X + Y
print(Z)
# Out:
# [[2 3 4]
#  [3 4 5]
#  [4 5 6]]

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D # <--- This is important for 3d plotting 

fig = plt.figure()
ax = fig.gca(projection="3d")
ax.plot_surface(X, Y, X + Y)

# %%
fig = plt.figure()
ax = fig.gca(projection="3d")
ax.plot_surface(X, Y, X**(1/2) + Y**(1/2))

# %%
fig = plt.figure()
ax = fig.gca(projection="3d")
ax.plot_surface(X, Y, X**(1/12) + Y**(12))

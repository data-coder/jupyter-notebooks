# %% [markdown]
# Return coordinate matrices from coordinate vectors.
#
# Make N-D coordinate arrays for vectorized evaluations of N-D scalar/vector fields over N-D grids, given one-dimensional coordinate arrays x1, x2,…, xn.
#
# The purpose of meshgrid is to create a rectangular grid out of an array of x values and an array of y values.

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D  # <--- This is important for 3d plotting

# %%
A = [1, 2, 3]
B = [4, 5, 6, 7]

# %%
J = np.meshgrid(A, B)
J
# Out:
# [array([[1, 2, 3],
#         [1, 2, 3],
#         [1, 2, 3],
#         [1, 2, 3]]),
#  array([[4, 4, 4],
#         [5, 5, 5],
#         [6, 6, 6],
#         [7, 7, 7]])]

# %%
J[0]
# Out:
# array([[1, 2, 3],
#        [1, 2, 3],
#        [1, 2, 3],
#        [1, 2, 3]])

# %%
J[1]
# Out:
# array([[4, 4, 4],
#        [5, 5, 5],
#        [6, 6, 6],
#        [7, 7, 7]])

# %%
fig = plt.figure(figsize=(5, 5))
ax = fig.add_subplot(111)
ax.scatter(A, [0, 0, 0], color='b', s=100)
ax.scatter([0, 0, 0, 0], B, color='r', s=100)
ax.set_xlim([0, 4])
ax.set_ylim([0, 8])
# Out:
# (0, 8)

# %%
fig = plt.figure(figsize=(5, 5))
ax = fig.add_subplot(111)
ax.scatter(A, [0, 0, 0], color='b', s=100)
ax.scatter([0, 0, 0, 0], B, color='r', s=100)

ax.plot(J[0], J[1], color='grey')

ax.set_xlim([0, 4])
ax.set_ylim([0, 8])
# Out:
# (0, 8)

# %%
fig = plt.figure(figsize=(5, 5))
ax = fig.add_subplot(111)
ax.scatter(A, [0, 0, 0], color='b', s=100)
ax.scatter([0, 0, 0, 0], B, color='r', s=100)

ax.plot(J[0], J[1], color='grey')

ax.plot([1, 3], [4, 4], color='grey')
ax.plot([1, 3], [5, 5], color='grey')
ax.plot([1, 3], [6, 6], color='grey')
ax.plot([1, 3], [7, 7], color='grey')

ax.set_xlim([0, 4])
ax.set_ylim([0, 8])
# Out:
# (0, 8)

# %%
fig = plt.figure(figsize=(5, 5))
ax = fig.add_subplot(111)
ax.scatter(A, [0, 0, 0], color='b', s=100)
ax.scatter([0, 0, 0, 0], B, color='r', s=100)

ax.plot(J[0], J[1], color='grey')
ax.plot([[1, 1, 1, 1], [3, 3, 3, 3]], [[4, 5, 6, 7], [4, 5, 6, 7]], color='grey')

ax.set_xlim([0, 4])
ax.set_ylim([0, 8])
# Out:
# (0, 8)

# %%
fig = plt.figure(figsize=(5, 5))
ax = fig.add_subplot(111)
ax.scatter(A, [0, 0, 0], color='b', s=100)
ax.scatter([0, 0, 0, 0], B, color='r', s=100)

ax.plot(J[0], J[1], color='grey')

ax.plot([1, 3], [4, 4], color='grey')
ax.plot([1, 3], [5, 5], color='grey')
ax.plot([1, 3], [6, 6], color='grey')
ax.plot([1, 3], [7, 7], color='grey')

ax.scatter(J[0], J[1], color='g', s=100)

ax.set_xlim([0, 4])
ax.set_ylim([0, 8])
# Out:
# (0, 8)

# %%
fig = plt.figure(figsize=(10, 10))
ax = fig.add_subplot(111, projection='3d')
ax.scatter(A, [0, 0, 0], color='b', s=100)
ax.scatter([0, 0, 0, 0], B, color='r', s=100)
ax.set_xlim([0, 4])
ax.set_ylim([0, 8])
ax.set_zlim([0, 1])
# Out:
# (0, 1)

# %%
fig = plt.figure(figsize=(10, 10))
ax = fig.add_subplot(111, projection='3d')
ax.scatter(A, [0, 0, 0], color='b', s=100)
ax.scatter([0, 0, 0, 0], B, color='r', s=100)
ax.scatter(J[0], J[1], color='g', s=100)
ax.set_xlim([0, 4])
ax.set_ylim([0, 8])
ax.set_zlim([0, 1])
# Out:
# (0, 1)

# %% [markdown]
# For surface plots, a meshgrid is needed.
#
# Now, I'll add the z values. Since we usually will have observations in the form (X, Y, Z), the vectors to be meshed are of the same size. This means that the meshgrid will be a square and not a rectangle, like in the above example.
#
# In this example, I'll use 1x3 vectors. Let's assume we have only three observations:
# Observation 1: (Feature1=1, Feature=4, value=10)
# Observation 2: (Feature1=2, Feature=5, value=11)
# Observation 3: (Feature1=3, Feature=6, value=12)
#
# Then, the vectors are:

# %%
D = [1, 2, 3]
E = [4, 5, 6]
Z_values = [10, 11, 12]

# %%
K = np.meshgrid(D, E)
K
# Out:
# [array([[1, 2, 3],
#         [1, 2, 3],
#         [1, 2, 3]]),
#  array([[4, 4, 4],
#         [5, 5, 5],
#         [6, 6, 6]])]

# %% [markdown]
# Firs, we need to create a grid on the "base" of the plot:

# %%
fig = plt.figure(figsize=(10, 10))
ax = fig.add_subplot(111, projection='3d')
ax.scatter(D, [0, 0, 0], color='b', s=100)
ax.scatter([0, 0, 0], E, color='r', s=100)
ax.scatter(K[0], K[1], color='g', s=100)
ax.set_xlim([0, 4])
ax.set_ylim([0, 8])
ax.set_zlim([0, 15])
# Out:
# (0, 15)

# %% [markdown]
# The grid has nine points: 3 features times 3 features.
#
# Now I add the Z values. We need nine points. If all values were 10, we'd had:

# %%
fig = plt.figure(figsize=(10, 10))
ax = fig.add_subplot(111, projection='3d')
ax.scatter(D, [0, 0, 0], color='b', s=100)
ax.scatter([0, 0, 0], E, color='r', s=100)
ax.scatter(K[0], K[1], color='g', s=100)
ax.scatter(K[0], K[1], [10, 10, 10, 10, 10, 10, 10, 10, 10], color='black', s=100)
ax.set_xlim([0, 4])
ax.set_ylim([0, 8])
ax.set_zlim([0, 15])
# Out:
# (0, 15)

# %%
fig = plt.figure(figsize=(10, 10))
ax = fig.add_subplot(111, projection='3d')
ax.scatter(D, [0, 0, 0], color='b', s=100)
ax.scatter([0, 0, 0], E, color='r', s=100)
ax.scatter(K[0], K[1], color='g', s=100)
ax.scatter(K[0], K[1], [10, 10, 10, 10, 10, 10, 10, 10, 10], color='black', s=10)
ax.plot(D, E, Z_values, color='black')
ax.set_xlim([0, 4])
ax.set_ylim([0, 8])
ax.set_zlim([0, 15])
# Out:
# (0, 15)

# %%
fig = plt.figure(figsize=(10, 10))
ax = fig.add_subplot(111, projection='3d')

# ax.scatter(D, [0, 0, 0], color='b', s=100)
# ax.scatter([0, 0, 0], E, color='r', s=100)
# ax.scatter(K[0], K[1], color='g', s=100)
# ax.scatter(K[0], K[1], [10, 10, 10, 10, 10, 10, 10, 10, 10], color='black', s=100)

ax.plot_surface(np.array([[0, 2, 6], [1, 1, 1]]),
                  np.array([[0, 2, 6], [2, 2, 2]]),
                  np.array([[5, 6, 7], [10, 10, 10]]))

#ax.set_xlim([0, 4])
#ax.set_ylim([0, 8])
#ax.set_zlim([0, 15])

# %%
np.array([[1, 1], [2, 2]])
# Out:
# array([[1, 1],
#        [2, 2]])

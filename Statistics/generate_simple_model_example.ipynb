# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# to import my own custom modules
# add my module’s sub-directory to Pythons path
import sys
import os
# module for plotting
sys.path.insert(0, os.path.abspath('/home/fede/Documents/Learn/Private_Scripts/Statistics/'))
# /home/fede/Documents/Learn/Private_Scripts/Statistics/fplots.py
import fplots

LOGO = 'datacomy.com'

# %%
# Example on how to use fplots
# Plot size and style is defined in /home/fede/Documents/Learn/Private_Scripts/Statistics/fplots.py
fblue = fplots.FBLUE
fred = fplots.FRED
X = list(range(0,100))
Y2 = [1000] * 100
Y1 = [i + e for i, e in zip(Y2, np.random.normal(0, 10, 100))]
# define each plot as a tuple
plot1 = ('scatterplot', X, Y1, fblue)
plot2 = ('lineplot', X, Y2, fred)
# create the plot
fplots.multiple_plots('x', 'y', 'title', *[plot1, plot2])

# %% [markdown]
# ## 2D Model
#
# Model with only one variable

# %%
price = np.arange(100, 200)
sales_predicted = np.array([1000 - 2 * p for p in price])
sales_observed = np.array(
    [1000 - 2 * p + r for p, r in zip(price, np.random.normal(0, 10, 100))]
)

# %% [markdown]
# ### Plots

# %%
plot1 = ('scatterplot', price, sales_observed, fplots.FBLUE)
fplots.multiple_plots('Price', 'Sales', '', plot1, logo=LOGO)

# %%
fig, ax = plt.subplots(figsize=(5, 5))
sns.scatterplot(x=price, y=sales_observed)
sns.lineplot(x=price, y=sales_predicted, color="red")
ax.set_xlabel("price")
ax.set_ylabel("sales")
# Out:
# Text(0, 0.5, 'sales')

# %%
fig, ax = plt.subplots(figsize=(5, 5))
sns.scatterplot(x=price, y=sales_observed)
sns.lineplot(x=price, y=sales_predicted, color="red")
ax.set_xlabel("price")
ax.set_ylabel("sales")
ax.text(ax.get_xlim()[0], ax.get_ylim()[0], 'datacomy')
# Out:
# Text(95.03698924731184, 589.2263780567794, 'datacomy')

# %%
# the same using fplot module
TEMPPLOT1 = ('scatterplot', price, sales_observed, fblue)
TEMPPLOT2 = ('lineplot', price, sales_predicted, fred)
fplots.multiple_plots('Price', 'Sales', '', *[TEMPPLOT1, TEMPPLOT2], logo=LOGO)

# %%
# the same using fplot module
TEMPPLOT1 = ('scatterplot', price, sales_observed, fblue)
TEMPPLOT2 = ('lineplot', price, sales_predicted, fred)
fplots.multiple_plots('Price',
                      'Sales',
                      'Price and Sales',
                      *[TEMPPLOT1, TEMPPLOT2],
                      logo=LOGO,
                      save='/tmp/price-sales_predicted-1ivar.png')

# %% [markdown]
# ## 3D Model

# %%
price_2 = np.arange(100, 200)
advertising_expenditure_2 = np.random.normal(1000, 10, 100)
sales_predicted_2 = np.array(
    [1000 - 2 * p + 0.6 * a for p, a in zip(price, advertising_expenditure_2)]
)
sales_observed_2 = np.array(
    [
        1000 - 2 * p + 0.6 * a + r
        for p, a, r in zip(price, advertising_expenditure_2, np.random.normal(0, 20, 100))
    ]
)

# %%
fig, ax = plt.subplots(figsize=(5, 5))
sns.scatterplot(x=price_2, y=sales_observed_2)
ax.set_xlabel("price")
ax.set_ylabel("sales")
plt.savefig("/tmp/statistical-learning-sales-price.png")

# %%
fig, ax = plt.subplots(figsize=(5, 5))
sns.scatterplot(x=price, y=sales_observed_2)
sns.lineplot(x=price_2, y=sales_predicted_2, color="red")
ax.set_xlabel("price")
ax.set_ylabel("sales")
plt.savefig("/tmp/statistical-learning-sales-price.png")

# %%
fig, ax = plt.subplots(figsize=(5, 5))
sns.scatterplot(x=advertising_expenditure_2, y=sales_observed_2)
ax.set_xlabel("advertising expenditure")
ax.set_ylabel("sales")
plt.savefig("/tmp/statistical-learning-sales-advertising.png")

# %%
fig, ax = plt.subplots(figsize=(5, 5))
sns.scatterplot(x=advertising_expenditure_2, y=sales_observed_2)
sns.lineplot(x=advertising_expenditure_2, y=sales_predicted_2, color="red")
ax.set_xlabel("advertising expenditure")
ax.set_ylabel("sales")
plt.savefig("/tmp/statistical-learning-sales-advertising.png")

# %%
fig, ax = plt.subplots(figsize=(10, 10))
ax = plt.axes(projection="3d")
ax.scatter3D(price, advertising_expenditure_2, sales_observed_2)
ax.set_xlabel("price")
ax.set_ylabel("advertising expenditure")
ax.set_zlabel("sales")
plt.savefig("/tmp/statistical-learning-sales-price-advertising.png")

# %%
fig, ax = plt.subplots(figsize=(10, 10))
ax = plt.axes(projection="3d")
ax.scatter3D(price, advertising_expenditure_2, sales_observed_2)
ax.plot_trisurf(price, advertising_expenditure_2, sales_observed_2, alpha='0.4',
                lw=0.2, edgecolor="black", color="grey")
ax.set_xlabel("price")
ax.set_ylabel("advertising expenditure")
ax.set_zlabel("sales")
ax.text(ax.get_xlim()[0], ax.get_ylim()[0], ax.get_zlim()[0], 'datacomy')
ax.set_title('Observations with 2 independent variables')
plt.savefig("/home/fede/datacomy.com/content/ml/statistical-learning/price-sales_observed-2ivar.png")

# %%
fig, ax = plt.subplots(figsize=(10, 10))
ax = plt.axes(projection="3d")
# ax.scatter3D(price, advertising_expenditure_2, sales_observed_2)

ax.plot_surface(price, advertising_expenditure_2, sales_predicted_2, color="red")



ax.set_xlabel("price")
ax.set_ylabel("advertising expenditure")
ax.set_zlabel("sales")
plt.savefig("/tmp/statistical-learning-sales-price-advertising.png")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-40-b63fb78bbc18> in <module>
#       3 # ax.scatter3D(price, advertising_expenditure_2, sales_observed_2)
#       4
# ----> 5 ax.plot_surface(price, advertising_expenditure_2, sales_predicted_2, color="red")
#       6
#       7
#
# ~/anaconda3/envs/fede/lib/python3.7/site-packages/mpl_toolkits/mplot3d/axes3d.py in plot_surface(self, X, Y, Z, norm, vmin, vmax, lightsource, *args, **kwargs)
#    1580
#    1581         if Z.ndim != 2:
# -> 1582             raise ValueError("Argument Z must be 2-dimensional.")
#    1583         if np.any(np.isnan(Z)):
#    1584             cbook._warn_external(
#
# ValueError: Argument Z must be 2-dimensional.

# %%
# This import registers the 3D projection, but is otherwise unused.
from mpl_toolkits.mplot3d import Axes3D  # noqa: F401 unused import

import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib.ticker import LinearLocator, FormatStrFormatter
import numpy as np


fig = plt.figure()
ax = fig.gca(projection="3d")

# Make data.
X = np.arange(-5, 5, 0.25)
Y = np.arange(-5, 5, 0.25)
X, Y = np.meshgrid(X, Y)
R = np.sqrt(X ** 2 + Y ** 2)
Z = np.sin(R)

# Plot the surface.
surf = ax.plot_surface(
    price, advertising_expenditure_2, sales_predicted, antialiased=False
)


plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-22-1d564f0da2f1> in <module>
#      20 # Plot the surface.
#      21 surf = ax.plot_surface(
# ---> 22     price, advertising_expenditure_2, sales_predicted, antialiased=False
#      23 )
#      24
#
# ~/anaconda3/envs/fede/lib/python3.7/site-packages/mpl_toolkits/mplot3d/axes3d.py in plot_surface(self, X, Y, Z, norm, vmin, vmax, lightsource, *args, **kwargs)
#    1580
#    1581         if Z.ndim != 2:
# -> 1582             raise ValueError("Argument Z must be 2-dimensional.")
#    1583         if np.any(np.isnan(Z)):
#    1584             cbook._warn_external(
#
# ValueError: Argument Z must be 2-dimensional.

# %%
# This import registers the 3D projection, but is otherwise unused.
from mpl_toolkits.mplot3d import Axes3D  # noqa: F401 unused import

import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib.ticker import LinearLocator, FormatStrFormatter
import numpy as np


fig = plt.figure()
ax = fig.gca(projection="3d")

# Make data.
X = np.arange(-5, 5, 0.25)
Y = np.arange(-5, 5, 0.25)
X, Y = np.meshgrid(X, Y)
R = np.sqrt(X ** 2 + Y ** 2)
Z = np.sin(R)
print(R.shape)
print(Z.shape)
print(price.shape)

# Plot the surface.
surf = ax.plot_surface(X, Y, Z, cmap=cm.coolwarm, linewidth=0, antialiased=False)

# Customize the z axis.
ax.set_zlim(-1.01, 1.01)
ax.zaxis.set_major_locator(LinearLocator(10))
ax.zaxis.set_major_formatter(FormatStrFormatter("%.02f"))

# Add a color bar which maps values to colors.
fig.colorbar(surf, shrink=0.5, aspect=5)

plt.show()
print(X)
print(Y)
print(Z)
print(R)
# Out:
# (40, 40)
# (40, 40)
# (100,)
# [[-5.   -4.75 -4.5  ...  4.25  4.5   4.75]
#  [-5.   -4.75 -4.5  ...  4.25  4.5   4.75]
#  [-5.   -4.75 -4.5  ...  4.25  4.5   4.75]
#  ...
#  [-5.   -4.75 -4.5  ...  4.25  4.5   4.75]
#  [-5.   -4.75 -4.5  ...  4.25  4.5   4.75]
#  [-5.   -4.75 -4.5  ...  4.25  4.5   4.75]]
# [[-5.   -5.   -5.   ... -5.   -5.   -5.  ]
#  [-4.75 -4.75 -4.75 ... -4.75 -4.75 -4.75]
#  [-4.5  -4.5  -4.5  ... -4.5  -4.5  -4.5 ]
#  ...
#  [ 4.25  4.25  4.25 ...  4.25  4.25  4.25]
#  [ 4.5   4.5   4.5  ...  4.5   4.5   4.5 ]
#  [ 4.75  4.75  4.75 ...  4.75  4.75  4.75]]
# [[ 0.70886129  0.57562789  0.42921793 ...  0.27541086  0.42921793
#    0.57562789]
#  [ 0.57562789  0.4208019   0.2570234  ...  0.09046523  0.2570234
#    0.4208019 ]
#  [ 0.42921793  0.2570234   0.08068791 ... -0.09334004  0.08068791
#    0.2570234 ]
#  ...
#  [ 0.27541086  0.09046523 -0.09334004 ... -0.26940744 -0.09334004
#    0.09046523]
# ...

# %%
print(f'R shape {R.shape}')
print(f'Z shape {Z.shape}')
print(f'X shape {Y.shape}')
# Out:
# R shape (40, 40)
# Z shape (40, 40)
# X shape (40, 40)

# %% [markdown]
# **Solutions to Selected Problems**

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn

# %% [markdown]
# # Chapter 1

# %% [markdown]
# ## 1.1
#
# (a) line (b) plane (c) same plane

# %% [markdown]
# # 1.2

# %%
v = np.array([4, 1])
w = np.array([-2, 2])
print(v + w) # solution to 2.1
print(v - w) # solution to 2.2


V = np.array([[1,1],[-2,2],[4,-7]])
origin = [0], [0] # origin point

plt.quiver(*origin, V[:,0], V[:,1], color=['r','b','g'], scale=21)
plt.show()
# Out:
# [2 3]
# [ 6 -1]

# %%
plt.quiver([0], [0], [1], [1], angles='xy', scale_units='xy', scale=1)
plt.xlim(-10, 10)
plt.ylim(-10, 10)
plt.show()

# %%
origin2d = np.array([0,0])
v = np.array([4, 1])
w = np.array([-2, 2])
print(v + w) # solution to 2.1
print(v - w) # solution to 2.2

def quiver2d(fvector,color = 'black',ovector = np.array([0,0])):
    plt.quiver(ovector[0],ovector[1],fvector[0],fvector[1], color = color,units='xy',scale=1)
def quiver2d_op(vector1,vector2,operation,color = 'black'):
    if operation == 'sum':
        plt.quiver(vector1[0], vector1[1],vector2[0],vector2[1],color = color,units='xy',scale=1)
        plt.quiver(0, 0,vector1[0]+ vector2[0],vector1[1]+ vector2[1],color = 'grey',units='xy',scale=1,width=0.01,headwidth=1,headlength=0)
    if operation == 'substraction':
        plt.quiver(vector1[0], vector1[1],-vector2[0],-vector2[1],color = color,units='xy',scale=1)
    

plt.figure(figsize=(10,10))
#plt.quiver(0,0,4,1,units='xy' ,scale=1, color='g')
#plt.quiver(0,0,-2,2,units='xy' ,scale=1, color='r')
plt.grid()
plt.xlim(-6, 6)
plt.ylim(-6, 6)

quiver2d(v, 'r')
quiver2d(w, 'g')
#plt.quiver(4,1,-2,2,units='xy' ,scale=1, color='b')
quiver2d_op(v,w,'sum')
plt.quiver(4,1,2,-2,units='xy' ,scale=1, color='y')
quiver2d_op(v,w,'substraction')
# Out:
# [2 3]
# [ 6 -1]

# %%
#seaborn.set(style='ticks')
fig, ax = plt.subplots(figsize=(10,10))
ax.quiver(0,0,2,3,units='xy' ,scale=1, color='b')
ax.grid(True, which='both')
ax.set_aspect('equal')
ax.axhline(color = 'black') # add horizontal axis line
ax.axvline(color = 'black')
seaborn.despine(ax=ax, offset=0) # the important part here
plt.xlim(-6, 6)
plt.ylim(-6, 6)
# Out:
# (-6, 6)
